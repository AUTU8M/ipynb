# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

sns.set_style('white')
# %matplotlib inline

# %%
movies_df = pd.read_csv("movies.csv")
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings_df = pd.read_csv("ratings.csv")
ratings_df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
merged_df = pd.merge(movies_df, ratings_df)
merged_df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
merged_df.drop(columns= ["timestamp"], inplace = True)
merged_df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
print(sorted(merged_df["genres"].unique()))
# Out:
# ['(no genres listed)', 'Action', 'Action|Adventure', 'Action|Adventure|Animation', 'Action|Adventure|Animation|Children', 'Action|Adventure|Animation|Children|Comedy', 'Action|Adventure|Animation|Children|Comedy|Fantasy', 'Action|Adventure|Animation|Children|Comedy|IMAX', 'Action|Adventure|Animation|Children|Comedy|Romance', 'Action|Adventure|Animation|Children|Comedy|Sci-Fi', 'Action|Adventure|Animation|Children|Comedy|Sci-Fi|IMAX', 'Action|Adventure|Animation|Children|Comedy|Western', 'Action|Adventure|Animation|Children|Fantasy', 'Action|Adventure|Animation|Children|Fantasy|Sci-Fi', 'Action|Adventure|Animation|Children|Sci-Fi', 'Action|Adventure|Animation|Comedy', 'Action|Adventure|Animation|Comedy|Crime|Mystery', 'Action|Adventure|Animation|Comedy|Fantasy|Mystery|Sci-Fi', 'Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi', 'Action|Adventure|Animation|Comedy|Sci-Fi', 'Action|Adventure|Animation|Comedy|Thriller', 'Action|Adventure|Animation|Crime|Fantasy', 'Action|Adventure|Animati
# ...

# %%
merged_df["genres"].replace("(no genres listed)", " ", inplace = True)
print(sorted(merged_df["genres"].unique()))
# Out:
# [' ', 'Action', 'Action|Adventure', 'Action|Adventure|Animation', 'Action|Adventure|Animation|Children', 'Action|Adventure|Animation|Children|Comedy', 'Action|Adventure|Animation|Children|Comedy|Fantasy', 'Action|Adventure|Animation|Children|Comedy|IMAX', 'Action|Adventure|Animation|Children|Comedy|Romance', 'Action|Adventure|Animation|Children|Comedy|Sci-Fi', 'Action|Adventure|Animation|Children|Comedy|Sci-Fi|IMAX', 'Action|Adventure|Animation|Children|Comedy|Western', 'Action|Adventure|Animation|Children|Fantasy', 'Action|Adventure|Animation|Children|Fantasy|Sci-Fi', 'Action|Adventure|Animation|Children|Sci-Fi', 'Action|Adventure|Animation|Comedy', 'Action|Adventure|Animation|Comedy|Crime|Mystery', 'Action|Adventure|Animation|Comedy|Fantasy|Mystery|Sci-Fi', 'Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi', 'Action|Adventure|Animation|Comedy|Sci-Fi', 'Action|Adventure|Animation|Comedy|Thriller', 'Action|Adventure|Animation|Crime|Fantasy', 'Action|Adventure|Animation|Drama', 'Actio
# ...

# %%
merged_df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
movies_df.shape
# Out:
# (9742, 3)

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_df.columns.values
# Out:
# array(['movieId', 'title', 'genres'], dtype=object)

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
movies_df.isnull().sum()#to summarize all the data together
#you can use it to calculate the missing values
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
sns.countplot(movies_df['movieId'])
rating=round((movies_df['movieId'].value_counts().values[0]/9742)/100)

# %%
print((movies_df['genres'].value_contents()/9742*100))
sns.countplot(movies_df['genres'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 print((movies_df['genres'].value_contents()/9742*100))
#       2 sns.countplot(movies_df['genres'])
#
# File c:\Users\shubh\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_contents'

# %%
print((merged_df['title'].value_contents()/9742*100))
sns.countplot(merged_df['title'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print((merged_df['title'].value_contents()/9742*100))
#       2 sns.countplot(merged_df['title'])
#
# File c:\Users\shubh\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_contents'

# %%
#here we are calculating the kurosis and the skewness of the plot
sns distplot(movies_df[movieId])
print(movies_df['movieId'].skew)
print(movies_df['movieId'].kurt)
# Out:
#   Cell In[31], line 2
#     sns distplot(movies_df[movieId])
#         ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(merged_df,size=5)
# Out:
# c:\Users\shubh\anaconda3\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# plot graph of 'num of ratings column'
plt.figure(figsize =(10, 3))
type(merged_df['rating'])
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize =(10, 4))
merged_df['rating'].hist(bins = 70)
# Out:
# <Axes: >

# %%
# Sorting values according to
# the 'num of rating column'
moviemat = data.pivot_table(index ='user_id',
			columns ='title', values ='rating')

moviemat.head()

ratings.sort_values('num of ratings', ascending = False).head(10)
